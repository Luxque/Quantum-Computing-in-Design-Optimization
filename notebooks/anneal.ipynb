# %% [markdown]
# # Quantum Optimization and Quantum Annealing (QA)

# %% [markdown]
# ## Formalizing Optimization Problems

# %% [markdown]
# ## Aidabatic Quantum Computing

# %% [markdown]
# ## Quantum Annealing
